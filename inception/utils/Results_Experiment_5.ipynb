# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plotting import *

# %%
dataDir = "."

# %%
list_of_runs = []
# If list is empty, all runs of the following experiment will be loaded
experimentName='LongRun-16-seed-8732'

# %%
M = 16

# %% [markdown]
# ### If list of runs is empty, load all runs from [experimentName]

# %%
if len(list_of_runs)==0:
    for folder in listdir(dataDir):
        if folder[:len(experimentName)]==experimentName:
            list_of_runs.append(folder)

# %% [markdown]
# ### Load listed runs

# %%
loss_results, acc_results = load_list_of_runs(list_of_runs)
# Out:
# Loading run logs:
# -----------------
# LongRun-16-seed-8732-0.0005--0.3-False
# LongRun-16-seed-8732-0.0005-0.0-False
# LongRun-16-seed-8732-0.0005-0.3-False
# LongRun-16-seed-8732-0.0005-0.3-True
# LongRun-16-seed-8732-0.0005-0.6-True
# LongRun-16-seed-8732-0.0005-0.9-True
# LongRun-16-seed-8732-0.001--0.3-False
# LongRun-16-seed-8732-0.001-0.0-False
# LongRun-16-seed-8732-0.001-0.3-False
# LongRun-16-seed-8732-0.001-0.3-True
# LongRun-16-seed-8732-0.001-0.6-True
# LongRun-16-seed-8732-0.001-0.9-True
# LongRun-16-seed-8732-0.005--0.3-False
# LongRun-16-seed-8732-0.005-0.0-False
# LongRun-16-seed-8732-0.005-0.3-False
# LongRun-16-seed-8732-0.005-0.3-True
# LongRun-16-seed-8732-0.005-0.6-True
# LongRun-16-seed-8732-0.005-0.9-True
# LongRun-16-seed-8732-0.01--0.3-False
# LongRun-16-seed-8732-0.01-0.0-False
# LongRun-16-seed-8732-0.01-0.3-False

# %% [markdown]
# ## Load times

# %%
times = load_times(list_of_runs, M=16)
# Out:
# Loading run logs:
# -----------------
# LongRun-16-seed-8732-0.0005--0.3-False
# LongRun-16-seed-8732-0.0005-0.0-False
# LongRun-16-seed-8732-0.0005-0.3-False
# LongRun-16-seed-8732-0.0005-0.3-True
# LongRun-16-seed-8732-0.0005-0.6-True
# LongRun-16-seed-8732-0.0005-0.9-True
# LongRun-16-seed-8732-0.001--0.3-False
# LongRun-16-seed-8732-0.001-0.0-False
# LongRun-16-seed-8732-0.001-0.3-False
# LongRun-16-seed-8732-0.001-0.3-True
# LongRun-16-seed-8732-0.001-0.6-True
# LongRun-16-seed-8732-0.001-0.9-True
# LongRun-16-seed-8732-0.005--0.3-False
# LongRun-16-seed-8732-0.005-0.0-False
# LongRun-16-seed-8732-0.005-0.3-False
# LongRun-16-seed-8732-0.005-0.3-True
# LongRun-16-seed-8732-0.005-0.6-True
# LongRun-16-seed-8732-0.005-0.9-True
# LongRun-16-seed-8732-0.01--0.3-False
# LongRun-16-seed-8732-0.01-0.0-False
# LongRun-16-seed-8732-0.01-0.3-False

# %% [markdown]
# ##  Get basic timing stats

# %%
SYNC_SECONDS_PER_BATCH, ASYNC_SECONDS_PER_BATCH = mean_times(times, M=M)
# Out:
# LongRun-16-seed-8732-0.001--0.3-False :	20.2601199461
# LongRun-16-seed-8732-0.0005--0.3-False :	20.3058577348
# LongRun-16-seed-8732-0.005-0.9-True :	21.9644833068
# LongRun-16-seed-8732-0.0005-0.3-False :	20.5294124294
# LongRun-16-seed-8732-0.0005-0.0-False :	20.1720013774
# LongRun-16-seed-8732-0.005-0.3-False :	20.3892819807
# LongRun-16-seed-8732-0.01--0.3-False :	20.1942532808
# LongRun-16-seed-8732-0.0005-0.9-True :	21.4948154312
# LongRun-16-seed-8732-0.0005-0.6-True :	24.9346580882
# LongRun-16-seed-8732-0.005-0.0-False :	20.17892
# LongRun-16-seed-8732-0.005-0.3-True :	21.8596134185
# LongRun-16-seed-8732-0.005--0.3-False :	20.1094832041
# LongRun-16-seed-8732-0.005-0.6-True :	22.2535540984
# LongRun-16-seed-8732-0.001-0.3-False :	20.206877551
# LongRun-16-seed-8732-0.01-0.0-False :	20.2231281374
# LongRun-16-seed-8732-0.001-0.6-True :	22.4759342327
# LongRun-16-seed-8732-0.0005-0.3-True :	22.0111065574
# LongRun-16-seed-8732-0.001-0.0-False :	20.176
# LongRun-16-seed-8732-0.01-0.3-False :	20.2646412316
# LongRun-16-seed-8732-0.001-0.9-True :	24.5985996441
#
# ------------------------------------------------------
# Mode	Mean batch time	Mean (0-15min)	Mean (30-60min)
# ------------------------------------------------------
# Sync:	22.6990955972 	22.4184813508 	22.7068011693
# Async:	20.2508314061 	21.0926896797 	19.9105348229
# ------------------------------------------------------
#
# ------------------------------------------------------
# Mode	Mean batch time	Steps/worker	Active time
# ------------------------------------------------------
# Sync:	22.6990955972 	1813.125 	42.8711434423
# Async:	20.2508314061 	2218.25 	46.7931320486
# ------------------------------------------------------

# %% [markdown]
# ### HE at beginning

# %%
21.0857/22.418481
# Out:
# 0.9405498972031155

# %% [markdown]
# ### HE in the end

# %%
19.92217/22.7068
# Out:
# 0.8773658111226593

# %% [markdown]
# ## Histograms (overall, individual workers) and delays throughout for two pairs of sync/async runs

# %%
f1,f2,f3=plot_times(['LongRun-16-seed-8732-0.0005-0.3-False','LongRun-16-seed-8732-0.0005-0.3-True'], M=16)
# Out:
# Loading run logs:
# -----------------
# LongRun-16-seed-8732-0.0005-0.3-False
# LongRun-16-seed-8732-0.0005-0.3-True

# %%
f1,f2,f3=plot_times(['LongRun-16-seed-8732-0.005-0.3-False','LongRun-16-seed-8732-0.005-0.3-True'], M=16)
# Out:
# Loading run logs:
# -----------------
# LongRun-16-seed-8732-0.005-0.3-False
# LongRun-16-seed-8732-0.005-0.3-True

# %% [markdown]
# ## Overview of all smoothed curves

# %%
marker_dict = {'0.0005':'s', '0.001':'o', '0.005':'v'}
marker_dict = {'0.0005':'s', '0.001':'o', '0.005':'v', '0.01':'D'}
marker_dict = {'0.0':',', '0.0005':'s', '0.001':'o', '0.0025':'+', '0.005':'v', '0.01':'D', '0.025':'.', '0.05':'*', '0.1':'^'}

# %%
WINDOW = 400

# %%
f = plot_all_runs(loss_results, window=WINDOW, two_panels=True, marker_dict=marker_dict, mark_every=60,
                    axis=[None, None, 5.05, 5.20])
# Out:
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True

# %% [markdown]
# ## Parameter space loss contours

# %%
plot_loss_contour(loss_results, window=WINDOW, sync=True)
# Out:
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True

# %%
plot_loss_contour(loss_results, window=WINDOW, sync=False)

# %% [markdown]
# ## Only plot the best run for each momentum value in each mode

# %%
dict_of_winners = get_best_for_each_momentum(loss_results,WINDOW)
# Out:
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True

# %% [markdown]
# ### DASHED = ASYNC
# ### SOLID = SYNC

# %%
f = plot_all_runs(dict_of_winners, window=WINDOW, two_panels=False, marker_dict=marker_dict, mark_every=100,
                 sync_seconds_per_batch=SYNC_SECONDS_PER_BATCH, async_seconds_per_batch=ASYNC_SECONDS_PER_BATCH,
                 CG=M)

# %%
f=plot_momentum_dependence(loss_results, WINDOW)
# Out:
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True

# %% [markdown]
# ## Plot winning curves along with evaluation loss level

# %%
f=plot_se_calculation(loss_results, WINDOW)
# Out:
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True

# %%
f=plot_winners_snr(loss_results, WINDOW)
# Out:
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True

# %% [markdown]
# # Plot HE-SE

# %%
f = plot_se_he(loss_results, WINDOW, M, SYNC_SECONDS_PER_BATCH, ASYNC_SECONDS_PER_BATCH)
# Out:
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True
# WARNING: Run shorter than window (0): LongRun-16-seed-8732-0.001-0.3-True

# %%
f.savefig('experiment5-se-he.png', bbox_inches='tight', pad_inches=0.1)

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
